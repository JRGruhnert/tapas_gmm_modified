# %% [markdown]
# ## Setup

# %%
# change into the src directory
import git
import os

repo = git.Repo('.', search_parent_directories=True)
os.chdir(repo.working_tree_dir)

# %%
from tapas_gmm_modified.policy.models.tpgmm import ModelType, TPGMM, ReconstructionStrategy, FittingStage, InitStrategy, _xdx_to_tangent, TPGMMConfig, AutoTPGMMConfig, AutoTPGMM, FrameSelectionConfig, DemoSegmentationConfig, CascadeConfig
# import lovely_tensors as lt
# lt.monkey_patch()
from lovely_numpy import lo
import matplotlib.pyplot as plt

import pathlib
#from pbdlib.utils.jupyter_utils import *
import numpy as np

from conf._machine import data_naming_config as machine_data_naming_config
from tapas_gmm_modified.dataset.demos import Demos, PartialFrameViewDemos
import tapas_gmm_modified.policy.models.tpgmm
from tapas_gmm_modified.utils.misc import load_scene_data, DataNamingConfig
from tapas_gmm_modified.utils.logging import setup_logger  # noqa: F401
from tapas_gmm_modified.viz.gmm import plot_log_map_quaternions, plot_hmm_transition_matrix

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

data_root = pathlib.Path(machine_data_naming_config.data_root).resolve()
data_root = data_root.parent / data_root.stem

np.set_printoptions(precision=2)

plt.style.use('default')

from IPython.display import HTML
from matplotlib import rc
rc('animation', html='jshtml')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#task = 'TurnOnLight'
serie = 'demos'
task = 'OpenDrawerBack'
path = data_root / task / serie

data_config = DataNamingConfig(
    feedback_type=None,
    task=None,
    data_root=None,
    path=path,
)

scene_data = load_scene_data(data_config)
print(scene_data.sample_data_point_with_ground_truth(cam="wrist"))
# Out:
# 2025-08-16 03:17:44.359 | INFO     |      Initializing datasete using /home/jangruhnert/Documents/GitHub/TapasCalvin/data/OpenDrawerBack/demos/metadata.json
# 2025-08-16 03:17:44.360 | INFO     |      Extracted gt object labels [0, 1, 2, 3, 4, 5, 6]
# 2025-08-16 03:17:44.360 | INFO     |      Extracted tsdf object labels []
# 2025-08-16 03:17:44.360 | INFO     |      Done! Data contains 5 trajectories.
# SingleCamSceneObservation(
#     action=Tensor(shape=torch.Size([7]), device=cpu, dtype=torch.float32, is_shared=False),
#     depth=Tensor(shape=torch.Size([256, 256]), device=cpu, dtype=torch.float32, is_shared=False),
#     ee_pose=Tensor(shape=torch.Size([7]), device=cpu, dtype=torch.float32, is_shared=False),
#     extr=Tensor(shape=torch.Size([4, 4]), device=cpu, dtype=torch.float32, is_shared=False),
#     feedback=Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#     intr=Tensor(shape=torch.Size([3, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#     mask=Tensor(shape=torch.Size([256, 256]), device=cpu, dtype=torch.uint8, is_shared=False),
#     object_poses=TensorDict(
#         fields={
#             base__button: Tensor(shape=torch.Size([7]), device=cpu, dtype=torch.float32, is_shared=False),
#             base__drawer: Tensor(shape=torch.Size([7]), device=cpu, dtype=torch.float32, is_shared=False),
#             base__slide: Tensor(shape=torch.Size([7]), device=cpu, dtype=torch.float32, is_shared=False),
#             base__switch: Tensor(shape=torch.Size([7]), device=cpu, dtype=torch.float32, is_shared=False),
#             block_blue: Tensor(shape=torch.Size([7]), device=cpu, dtype=torch.float32, is_shared=False),
#             block_pink: Tensor(shape=torch.Size([7]), device=cpu, dtype=torch.float32, is_shared=False),
#             block_red: Tensor(shape=torch.Size([7]), device=cpu, dtype=torch.float32, is_shared=False),
#             led: Tensor(shape=torch.Size([7]), device=cpu, dtype=torch.float32, is_shared=False),
#             lightbulb: Tensor(shape=torch.Size([7]), device=cpu, dtype=torch.float32, is_shared=False)},
#         batch_size=torch.Size([]),
#         device=cpu,
#         is_shared=False),
#     object_states=TensorDict(
#         fields={
#             base__button: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#             base__drawer: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#             base__slide: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#             base__switch: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#             block_blue: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#             block_pink: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#             block_red: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#             led: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False),
#             lightbulb: Tensor(shape=torch.Size([1]), device=cpu, dtype=torch.float32, is_shared=False)},
#         batch_size=torch.Size([]),
#         device=cpu,
#         is_shared=False),
#     rgb=Tensor(shape=torch.Size([3, 256, 256]), device=cpu, dtype=torch.float32, is_shared=False),
#     joint_pos=None,
#     joint_vel=None,
#     gripper_state=None,
#     descriptor=None,
#     batch_size=torch.Size([]),
#     device=None,
#     is_shared=False)

# %%
gt_pose_config = {
    #'indeces': [1,2,3,4],
}

gt_kp_config = {
    'encoder_name': 'demos_keypoints_gt_encoder-world',
    'cam': 'front',
}

kp_config = {
    'encoder_name': 'demos_vit_keypoints_encoder',
    'encoding_name': 'gtcopy',
}

# %%
observations = scene_data.get_demos(**gt_pose_config)
print(observations[0].keys())
print(observations[0])
n_obs = len(observations)

demo_meta_data = {
    'path': path
}

data_kwargs = dict(
    meta_data=demo_meta_data,
    add_init_ee_pose_as_frame=True,
    add_world_frame=False,
    frames_from_keypoints=False,
    kp_indeces=None,
    enforce_z_up=False,
    modulo_object_z_rotation=False,
    make_quats_continuous=True
)

demos = Demos(observations, **data_kwargs)
print(demos)
# Out:
# _LazyStackedTensorDictKeysView(['action', 'cameras', 'ee_pose', 'feedback', 'gripper_state', 'joint_pos', 'joint_vel', 'object_poses', 'object_states'],
#     include_nested=False,
#     leaves_only=False)
# SceneObservation(
#     action=Tensor(shape=torch.Size([75, 7]), device=cpu, dtype=torch.float32, is_shared=False),
#     cameras=LazyStackedTensorDict(
#         fields={
#             _order: CameraOrder(
#                 order=('wrist',),
#                 batch_size=torch.Size([75]),
#                 device=None,
#                 is_shared=False),
#             wrist: SingleCamObservation(
#                 depth=Tensor(shape=torch.Size([75, 256, 256]), device=cpu, dtype=torch.float32, is_shared=False),
#                 extr=Tensor(shape=torch.Size([75, 4, 4]), device=cpu, dtype=torch.float32, is_shared=False),
#                 intr=Tensor(shape=torch.Size([75, 3, 3]), device=cpu, dtype=torch.float32, is_shared=False),
#                 rgb=Tensor(shape=torch.Size([75, 3, 256, 256]), device=cpu, dtype=torch.float32, is_shared=False),
#                 descriptor=None,
#                 mask=None,
#                 batch_size=torch.Size([75]),
#                 device=None,
#                 is_shared=False)},
#         exclusive_fields={
#         },
#         batch_size=torch.Size([75]),
#         device=None,
#         is_shared=False,
#         stack_dim=0),
#     ee_pose=Tensor(shape=torch.Size([75, 7]), device=cpu, dtype=torch.float32, is_shared=False),
#     feedback=Tensor(shape=torch.Size([75, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#     gripper_state=Tensor(shape=torch.Size([75, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#     joint_pos=Tensor(shape=torch.Size([75, 7]), device=cpu, dtype=torch.float32, is_shared=False),
#     joint_vel=Tensor(shape=torch.Size([75, 7]), device=cpu, dtype=torch.float32, is_shared=False),
#     object_poses=LazyStackedTensorDict(
#         fields={
#             base__button: Tensor(shape=torch.Size([75, 7]), device=cpu, dtype=torch.float32, is_shared=False),
#             base__drawer: Tensor(shape=torch.Size([75, 7]), device=cpu, dtype=torch.float32, is_shared=False),
#             base__slide: Tensor(shape=torch.Size([75, 7]), device=cpu, dtype=torch.float32, is_shared=False),
#             base__switch: Tensor(shape=torch.Size([75, 7]), device=cpu, dtype=torch.float32, is_shared=False),
#             block_blue: Tensor(shape=torch.Size([75, 7]), device=cpu, dtype=torch.float32, is_shared=False),
#             block_pink: Tensor(shape=torch.Size([75, 7]), device=cpu, dtype=torch.float32, is_shared=False),
#             block_red: Tensor(shape=torch.Size([75, 7]), device=cpu, dtype=torch.float32, is_shared=False),
#             led: Tensor(shape=torch.Size([75, 7]), device=cpu, dtype=torch.float32, is_shared=False),
#             lightbulb: Tensor(shape=torch.Size([75, 7]), device=cpu, dtype=torch.float32, is_shared=False)},
#         exclusive_fields={
#         },
#         batch_size=torch.Size([75]),
#         device=cpu,
#         is_shared=False,
#         stack_dim=0),
#     object_states=LazyStackedTensorDict(
#         fields={
#             base__button: Tensor(shape=torch.Size([75, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#             base__drawer: Tensor(shape=torch.Size([75, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#             base__slide: Tensor(shape=torch.Size([75, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#             base__switch: Tensor(shape=torch.Size([75, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#             block_blue: Tensor(shape=torch.Size([75, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#             block_pink: Tensor(shape=torch.Size([75, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#             block_red: Tensor(shape=torch.Size([75, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#             led: Tensor(shape=torch.Size([75, 1]), device=cpu, dtype=torch.float32, is_shared=False),
#             lightbulb: Tensor(shape=torch.Size([75, 1]), device=cpu, dtype=torch.float32, is_shared=False)},
#         exclusive_fields={
#         },
#         batch_size=torch.Size([75]),
#         device=cpu,
#         is_shared=False,
#         stack_dim=0),
#     kp=None,
#     batch_size=torch.Size([75]),
#     device=None,
#     is_shared=False)
# 2025-08-16 03:17:45.347 | INFO     |    Subsampling to length 69 using strategy mean-length.
# <tapas_gmm_modified.dataset.demos.Demos object at 0x7fa174c45360>

# %%
tag="release"

tpgmm_config = TPGMMConfig(
    n_components=10,
    model_type=ModelType.HMM,
    use_riemann=True,
    add_time_component=True,
    add_action_component=False,
    position_only=False,  # Use rotation aswell?
    add_gripper_action=True,
    heal_time_variance=False,
    reg_shrink=1e-2, # 1e-2 is 0.01
    reg_diag=2e-4,
    reg_diag_gripper=2e-2,
    reg_em_finish_shrink=1e-2,
    reg_em_finish_diag=2e-4,
    reg_em_finish_diag_gripper=2e-2,

    em_steps=50,
)

frame_selection_config = FrameSelectionConfig(
    init_strategy=InitStrategy.TIME_BASED,
    fitting_actions=(FittingStage.INIT,),
    rel_score_threshold=0.75,
    use_bic=False,  # Does prune segmentation
    drop_redundant_frames=True,
    gt_frames=[
        [0, 2],
        [0, 2],
        [0, 2],
    ],
)

demos_segmentation_config = DemoSegmentationConfig(
    gripper_based=False,
    distance_based=False,
    velocity_based=True,
    velocity_threshold=0.001,
    components_prop_to_len=True,
    min_end_distance=0,
)

cascade_config = CascadeConfig()

auto_tpgmm_config = AutoTPGMMConfig(
    tpgmm=tpgmm_config,
    frame_selection=frame_selection_config,
    demos_segmentation=demos_segmentation_config,
    cascade=cascade_config,
)

# %%
atpgmm = AutoTPGMM(auto_tpgmm_config)

# %%
atpgmm.fit_trajectories(demos, fix_frames=True,
                       fitting_actions=(FittingStage.INIT,))
# Out:
# 2025-08-16 03:17:45.424 | INFO     |    Fitting AutoTPGMM
# 2025-08-16 03:17:45.424 | INFO     |    Performing fitting actions: [INIT]
# 2025-08-16 03:17:45.424 | INFO     |    Segmenting trajectories
# 2025-08-16 03:17:45.801 | INFO     |    Creating segement of demos.
# 2025-08-16 03:17:45.803 | INFO     |    Subsampling to length 14 using strategy mean-length.
# 2025-08-16 03:17:45.803 | INFO     |    Creating segement of demos.
# 2025-08-16 03:17:45.805 | INFO     |    Subsampling to length 62 using strategy mean-length.
# 2025-08-16 03:17:45.805 | INFO     |    Creating segement of demos.
# 2025-08-16 03:17:45.806 | INFO     |    Subsampling to length 18 using strategy mean-length.
# 2025-08-16 03:17:45.807 | INFO     |    ... created 3 segments
# 2025-08-16 03:17:45.807 | INFO     |      Fitting candidate frame 1/10
# 2025-08-16 03:17:45.807 | INFO     |      Creating partial frame view of demos.
# 2025-08-16 03:17:45.808 | INFO     |      Manifold: TIME x R3 x QUAT x R1
# 2025-08-16 03:17:45.808 | INFO     |      Changing number of components to 1
# 2025-08-16 03:17:45.808 | INFO     |      Init strategy not specified. Auto selected InitStrategy.TIME_BASED.
# 2025-08-16 03:17:45.808 | INFO     |      Model init ...
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:45.820 | INFO     |      Fitting candidate frame 2/10
# 2025-08-16 03:17:45.820 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:45.854 | INFO     |      Fitting candidate frame 3/10
# 2025-08-16 03:17:45.854 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:45.882 | INFO     |      Fitting candidate frame 4/10
# 2025-08-16 03:17:45.882 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:45.901 | INFO     |      Fitting candidate frame 5/10
# 2025-08-16 03:17:45.901 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:45.923 | INFO     |      Fitting candidate frame 6/10
# 2025-08-16 03:17:45.923 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:45.946 | INFO     |      Fitting candidate frame 7/10
# 2025-08-16 03:17:45.946 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:45.965 | INFO     |      Fitting candidate frame 8/10
# 2025-08-16 03:17:45.965 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:45.991 | INFO     |      Fitting candidate frame 9/10
# 2025-08-16 03:17:45.991 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:46.012 | INFO     |      Fitting candidate frame 10/10
# 2025-08-16 03:17:46.012 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:46.032 | INFO     |    ee_init    score (rel):     -0 (1.000)
# 2025-08-16 03:17:46.032 | INFO     |    base__button score (rel):     -0 (1.000)
# 2025-08-16 03:17:46.032 | INFO     |    base__drawer score (rel):     -0 (1.000)
# 2025-08-16 03:17:46.032 | INFO     |    base__slide score (rel):     -0 (0.003)
# 2025-08-16 03:17:46.032 | INFO     |    base__switch score (rel):     -0 (0.026)
# 2025-08-16 03:17:46.032 | INFO     |    block_blue score (rel):     -0 (0.000)
# 2025-08-16 03:17:46.032 | INFO     |    block_pink score (rel):     -0 (0.000)
# 2025-08-16 03:17:46.032 | INFO     |    block_red  score (rel):     -0 (0.000)
# 2025-08-16 03:17:46.032 | INFO     |    led        score (rel):     -0 (1.000)
# 2025-08-16 03:17:46.032 | INFO     |    lightbulb  score (rel):     -0 (1.000)
# 2025-08-16 03:17:46.032 | INFO     |    Dropping redundant frames [1 2 8 9].
# 2025-08-16 03:17:46.032 | WARNING  |    Using manual frame selection for debugging.
# 2025-08-16 03:17:46.033 | INFO     |    Creating partial frame view of demos.
# 2025-08-16 03:17:46.033 | INFO     |      Fitting candidate frame 1/10
# 2025-08-16 03:17:46.033 | INFO     |      Creating partial frame view of demos.
# 2025-08-16 03:17:46.036 | INFO     |      Changing number of components to 5
# Time-based init:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-08-16 03:17:46.170 | INFO     |      Fitting candidate frame 2/10
# 2025-08-16 03:17:46.170 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-08-16 03:17:46.272 | INFO     |      Fitting candidate frame 3/10
# 2025-08-16 03:17:46.272 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-08-16 03:17:46.365 | INFO     |      Fitting candidate frame 4/10
# 2025-08-16 03:17:46.366 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-08-16 03:17:46.455 | INFO     |      Fitting candidate frame 5/10
# 2025-08-16 03:17:46.455 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-08-16 03:17:46.564 | INFO     |      Fitting candidate frame 6/10
# 2025-08-16 03:17:46.564 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-08-16 03:17:46.670 | INFO     |      Fitting candidate frame 7/10
# 2025-08-16 03:17:46.670 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-08-16 03:17:46.762 | INFO     |      Fitting candidate frame 8/10
# 2025-08-16 03:17:46.762 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-08-16 03:17:46.852 | INFO     |      Fitting candidate frame 9/10
# 2025-08-16 03:17:46.852 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-08-16 03:17:46.942 | INFO     |      Fitting candidate frame 10/10
# 2025-08-16 03:17:46.942 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-08-16 03:17:47.032 | INFO     |    ee_init    score (rel):     -0 (0.997)
# 2025-08-16 03:17:47.032 | INFO     |    base__button score (rel):     -0 (0.997)
# 2025-08-16 03:17:47.032 | INFO     |    base__slide score (rel):     -0 (0.021)
# 2025-08-16 03:17:47.032 | INFO     |    base__switch score (rel):     -0 (0.042)
# 2025-08-16 03:17:47.032 | INFO     |    block_pink score (rel):     -0 (0.001)
# 2025-08-16 03:17:47.032 | INFO     |    block_red  score (rel):     -0 (0.001)
# 2025-08-16 03:17:47.032 | INFO     |    led        score (rel):     -0 (0.997)
# 2025-08-16 03:17:47.032 | INFO     |    lightbulb  score (rel):     -0 (0.997)
# 2025-08-16 03:17:47.033 | INFO     |    Dropping redundant frames [8 9].
# 2025-08-16 03:17:47.033 | INFO     |    Creating partial frame view of demos.
# 2025-08-16 03:17:47.034 | INFO     |      Fitting candidate frame 1/10
# 2025-08-16 03:17:47.034 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:47.056 | INFO     |      Fitting candidate frame 2/10
# 2025-08-16 03:17:47.056 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:47.080 | INFO     |      Fitting candidate frame 3/10
# 2025-08-16 03:17:47.080 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:47.102 | INFO     |      Fitting candidate frame 4/10
# 2025-08-16 03:17:47.102 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:47.125 | INFO     |      Fitting candidate frame 5/10
# 2025-08-16 03:17:47.125 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:47.148 | INFO     |      Fitting candidate frame 6/10
# 2025-08-16 03:17:47.148 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:47.170 | INFO     |      Fitting candidate frame 7/10
# 2025-08-16 03:17:47.170 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:47.192 | INFO     |      Fitting candidate frame 8/10
# 2025-08-16 03:17:47.193 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:47.215 | INFO     |      Fitting candidate frame 9/10
# 2025-08-16 03:17:47.215 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:47.240 | INFO     |      Fitting candidate frame 10/10
# 2025-08-16 03:17:47.240 | INFO     |      Creating partial frame view of demos.
# Time-based init:   0%|          | 0/1 [00:00<?, ?it/s]
# 2025-08-16 03:17:47.263 | INFO     |    ee_init    score (rel):     -0 (0.993)
# 2025-08-16 03:17:47.263 | INFO     |    base__button score (rel):     -0 (0.993)
# 2025-08-16 03:17:47.263 | INFO     |    base__slide score (rel):     -0 (0.010)
# 2025-08-16 03:17:47.263 | INFO     |    base__switch score (rel):     -0 (0.028)
# 2025-08-16 03:17:47.263 | INFO     |    led        score (rel):     -0 (0.993)
# 2025-08-16 03:17:47.263 | INFO     |    lightbulb  score (rel):     -0 (0.993)
# 2025-08-16 03:17:47.263 | INFO     |    Dropping redundant frames [1 8 9].
# 2025-08-16 03:17:47.263 | INFO     |    Creating partial frame view of demos.
# 2025-08-16 03:17:47.264 | INFO     |    Segmented trajs into 3 segments
# 2025-08-16 03:17:47.266 | INFO     |    Frame score (abs):
#             ee_init  base__button  base__drawer  base__slide  base__switch  \
# Segment 0 -0.198863     -0.198863     -0.198800    -0.000527     -0.005209
# Segment 1 -0.198863     -0.198863     -0.199499    -0.004284     -0.008319
# Segment 2 -0.198226     -0.198225     -0.199542    -0.001986     -0.005507
#
#            block_blue  block_pink  block_red       led  lightbulb
# Segment 0   -0.000002   -0.000004  -0.000007 -0.198863  -0.198863
# Segment 1   -0.000069   -0.000137  -0.000140 -0.198863  -0.198863
# Segment 2   -0.000008   -0.000027  -0.000028 -0.198225  -0.198225
# 2025-08-16 03:17:47.268 | INFO     |    Frame score (rel):
#             ee_init  base__button  base__drawer  base__slide  base__switch  \
# Segment 0  1.000000      1.000000      0.999688     0.002650      0.026196
# Segment 1  0.996810      0.996810      1.000000     0.021473      0.041702
# Segment 2  0.993404      0.993402      1.000000     0.009953      0.027600
#
#            block_blue  block_pink  block_red       led  lightbulb
# Segment 0    0.000011    0.000020   0.000033  1.000000   1.000000
# Segment 1    0.000345    0.000687   0.000699  0.996810   0.996810
# Segment 2    0.000042    0.000134   0.000140  0.993403   0.993402
# Fitting segments:   0%|          | 0/3 [00:00<?, ?it/s]
# 2025-08-16 03:17:47.274 | INFO     |    Manifold: TIME x R3 x QUAT x R3 x QUAT x R1
# 2025-08-16 03:17:47.274 | INFO     |    Changing number of components to 3
# Time-based init:   0%|          | 0/3 [00:00<?, ?it/s]
# Time-based init:   0%|          | 0
#           4.53e-002, 2.90e-004, 8.22e-008, 7.06e-013, 1.26e-019, 3.18e-028,
#           8.77e-039, 9.50e-051, 2.48e-063, 1.67e-076, 2.71e-090, 9.89e-105,
#           2.55e-025, 1.04e-005, 1.38e-003, 5.42e-002, 4.29e-001, 4.67e-001,
#           4.81e-002, 3.20e-004, 9.43e-008, 8.40e-013, 1.55e-019, 4.04e-028,
#           1.12e-038, 1.07e-050, 2.40e-063, 1.39e-076, 1.94e-090, 6.12e-105],
#          [6.42e-019, 6.42e-019, 1.09e-005, 1.44e-003, 5.67e-002, 4.88e-001,
#           9.52e-001, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000,
#           1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000,
#           1.19e-018, 1.19e-018, 1.62e-005, 1.89e-003, 6.71e-002, 5.21e-001,
#           9.60e-001, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000,
#           1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000,
#           5.81e-019, 5.81e-019, 9.36e-006, 1.29e-003, 5.31e-002, 4.74e-001,
#           9.49e-001, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000,
#           1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000,
#           8.02e-019, 8.02e-019, 1.23e-005, 1.56e-003, 5.95e-002, 4.97e-001,
#           9.54e-001, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000,
#           1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000,
#           7.40e-019, 7.40e-019, 1.04e-005, 1.39e-003, 5.56e-002, 4.84e-001,
#           9.52e-001, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000,
#           1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000, 1.00e+000]])),
#  (768.681585585552, 2794.604771236397, 946.0224400872196))

# %%
atpgmm.plot_model(
    scatter=True, rotations_raw=True, plot_traj=True, plot_gaussians=True,
    annotate_gaussians=True, annotate_trajs=False,
    mean_as_base=False, per_segment=False, gaussian_mean_only=False, plot_traj_means=False)
# Out:
# 2025-08-16 03:17:50.830 | INFO     |    Did not specify time_based, deciding automatically.

# %%
atpgmm.plot_model(
    scatter=True, rotations_raw=True, plot_traj=True, plot_gaussians=True,
    annotate_gaussians=True, annotate_trajs=False,
    mean_as_base=True, per_segment=False, gaussian_mean_only=False, plot_traj_means=True, time_based=True)

# %%
atpgmm.plot_hmm_transition_matrix()

# %%
atpgmm.to_disk(data_root / task / f'{serie}_gmm_policy-{tag}.pt')
# Out:
# 2025-08-16 03:17:53.126 | INFO     |    Saving model:

# %%
seg_local_marginals, seg_trans_marginals, seg_trans_marg_container, seg_joint_models, cascaded_hmms, (reconstructions, original_trajectories, extras) = atpgmm.reconstruct(
    strategy=tapas_gmm_modified.policy.models.tpgmm.ReconstructionStrategy.GMR,
    use_ss=False)
# Out:
# 2025-08-16 03:17:53.183 | INFO     |    Time-based reconstruction not specified. Auto selected True.
# 2025-08-16 03:18:10.929 | INFO     |    Caculated segment transition probabilities: (array([[0.]]), array([[1.88e-08]]))
# 2025-08-16 03:18:10.929 | WARNING  |    At least one segment transition prob below 5%. Can lead to problems.Consider increasing the diag reg.
# 2025-08-16 03:18:10.929 | INFO     |    Creating partial frame view of demos.
# 2025-08-16 03:18:10.931 | INFO     |    Assuming zero frame velocity. Should be fixed.
# Transforming marginals:   0%|          | 0/5 [00:00<?, ?it/s]
# Joining marginals:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-08-16 03:18:10.961 | INFO     |    Creating partial frame view of demos.
# Transforming marginals:   0%|          | 0/5 [00:00<?, ?it/s]
# Joining marginals:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-08-16 03:18:10.992 | INFO     |    Creating partial frame view of demos.
# Transforming marginals:   0%|          | 0/5 [00:00<?, ?it/s]
# Joining marginals:   0%|          | 0/5 [00:00<?, ?it/s]
# 2025-08-16 03:18:11.016 | WARNING  |    Setting init priors of later segments to zero.
# GMR:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
for cascaded_hmm in cascaded_hmms:
    plot_hmm_transition_matrix(cascaded_hmm)

# %%
atpgmm.plot_reconstructions(
    seg_trans_marg_container,
    cascaded_hmms,
    reconstructions,
    original_trajectories,
    plot_trajectories=True,
    plot_reconstructions=True,
    plot_gaussians=True,
    time_based=True,
    equal_aspect=False,
    per_segment=False,
)
# Out:
# 2025-08-16 03:18:12.250 | INFO     |    Taking frame origins from demos.

# %%
atpgmm.plot_reconstructions(
    seg_trans_marginals,
    seg_joint_models,
    reconstructions,
    original_trajectories,
    plot_trajectories=True,
    plot_reconstructions=True,
    plot_gaussians=True,
    time_based=True,
    equal_aspect=True,
    per_segment=False,
)
# Out:
# 2025-08-16 03:18:16.043 | INFO     |    Taking frame origins from demos.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 atpgmm.plot_reconstructions(
#       2     seg_trans_marginals,
#       3     seg_joint_models,
#       4     reconstructions,
#       5     original_trajectories,
#       6     plot_trajectories=True,
#       7     plot_reconstructions=True,
#       8     plot_gaussians=True,
#       9     time_based=True,
#      10     equal_aspect=True,
#      11     per_segment=False,
#      12 )
#
# File ~/Documents/GitHub/TapasCalvin/tapas_gmm_modified/policy/models/tpgmm.py:4035, in AutoTPGMM.plot_reconstructions(self, marginals, joint_models, reconstructions, original_trajectories, demos, time_based, per_segment, **kwargs)
#    4026     self._plot_reconstructions_per_segment(
#    4027         marginals=marginals,
#    4028         joint_models=joint_models,
#    (...)
#    4032         **kwargs,
#    4033     )
#    4034 else:
# -> 4035     self._plot_reconstructions_jointly(
#    4036         marginals=marginals,
#    4037         joint_models=joint_models,
#    4038         reconstructions=reconstructions,
#    4039         original_trajectories=original_trajectories,
#    4040         time_based=time_based,
#    4041         **kwargs,
#    4042     )
#
# File ~/Documents/GitHub/TapasCalvin/tapas_gmm_modified/policy/models/tpgmm.py:4113, in AutoTPGMM._plot_reconstructions_jointly(self, marginals, joint_models, reconstructions, original_trajectories, demos, time_based, frame_orig_wquats, **kwargs)
#    4108 frame_orig_wquats = frame_orig_wquats[:, self._used_frames]
#    4110 frame_names = [demos.frame_names[i] for i in self._used_frames]
#    4112 frame_origs_log = np.stack(
# -> 4113     [
#    4114         j.np_to_manifold_to_np(f, i_in=[1, 2])
#    4115         for j, f in zip(joint_models, frame_orig_wquats)
#    4116     ]
#    4117 )
#    4119 if reconstruction_is_per_segment:
#    4120     seg_lens = tuple(
#    4121         tuple(len(r) for r in recs) for recs in zip(*reconstructions)
#    4122     )
#
# File ~/Documents/GitHub/TapasCalvin/tapas_gmm_modified/policy/models/tpgmm.py:4114, in <listcomp>(.0)
#    4108 frame_orig_wquats = frame_orig_wquats[:, self._used_frames]
#    4110 frame_names = [demos.frame_names[i] for i in self._used_frames]
#    4112 frame_origs_log = np.stack(
#    4113     [
# -> 4114         j.np_to_manifold_to_np(f, i_in=[1, 2])
#    4115         for j, f in zip(joint_models, frame_orig_wquats)
#    4116     ]
#    4117 )
#    4119 if reconstruction_is_per_segment:
#    4120     seg_lens = tuple(
#    4121         tuple(len(r) for r in recs) for recs in zip(*reconstructions)
#    4122     )
#
# AttributeError: 'tuple' object has no attribute 'np_to_manifold_to_np'
